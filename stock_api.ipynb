# %%
import yfinance as yf

# %%
msft = yf.Ticker('MSFT')

# %%
yinn = yf.Ticker('YINN')

# %%
kweb = yf.Ticker('kweb')

# %%
kweb.info
# Out:
# {'previousClose': 43.36,
#  'regularMarketOpen': 46.22,
#  'twoHundredDayAverage': 47.109707,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': None,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 46.38,
#  'navPrice': 44.98,
#  'averageDailyVolume10Day': 3960571,
#  'totalAssets': 2459313664,
#  'regularMarketPreviousClose': 43.36,
#  'fiftyDayAverage': 49.873234,
#  'trailingAnnualDividendRate': None,
#  'open': 46.22,
#  'averageVolume10days': 3960571,
#  'expireDate': None,
#  'yield': 0.0008,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'beta': None,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 43,
#  'priceHint': 2,
#  'currency': 'USD',
#  'regularMarketVolume': 2499517,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': None,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 2866444,
#  'priceToSalesTrailing12Months': None,
#  'dayLow': 43,
#  'ask': 45.9,
#  'ytdReturn': None,
#  'askSize': 800,
#  'volume': 2499517,
#  'fiftyTwoWeekHigh': 54.77,
#  'forwardPE': None,
#  'maxAge': 1,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 38.01,
#  'bid': 41.35,
#  'tradeable': True,
#  'dividendYield': None,
#  'bidSize': 1000,
#  'dayHigh': 46.38,
#  'exchange': 'PCX',
#  'shortName': 'KraneShares Trust KraneShares C',
#  'longName': 'KraneShares CSI China Internet ETF',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'ETF',
#  'symbol': 'KWEB',
#  'messageBoardId': 'finmb_243136794',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': None,
#  'beta3Year': 1.51,
#  'profitMargins': None,
#  'enterpriseToEbitda': None,
#  '52WeekChange': None,
#  'morningStarRiskRating': None,
#  'forwardEps': None,
#  'revenueQuarterlyGrowth': None,
#  'fundInceptionDate': 1375228800,
#  'annualReportExpenseRatio': None,
#  'bookValue': None,
#  'fundFamily': 'KraneShares',
#  'lastFiscalYearEnd': None,
#  'netIncomeToCommon': None,
#  'trailingEps': None,
#  'lastDividendValue': None,
#  'SandP52WeekChange': None,
#  'priceToBook': None,
#  'nextFiscalYearEnd': None,
#  'mostRecentQuarter': None,
#  'enterpriseValue': None,
#  'threeYearAverageReturn': 0.0395,
#  'lastSplitDate': None,
#  'lastSplitFactor': None,
#  'legalType': 'Exchange Traded Fund',
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': None,
#  'pegRatio': None,
#  'lastCapGain': None,
#  'category': 'China Region',
#  'fiveYearAverageReturn': 0.084300004,
#  'phone': '855-857-2638',
#  'longBusinessSummary': 'The investment seeks to provide investment results that, before fees and expenses, correspond generally to the price and yield performance of the CSI Overseas China Internet Index.\n The fund invests at least 80% of its total assets in equity securities of the index and in depositary receipts representing such securities. The index is designed to measure the equity market performance of the investable universe of publicly traded China-based companies whose primary business or businesses are in the Internet and Internet-related sectors, and are listed outside of Mainland China, as determined by the index provider. The fund is non-diversified.',
#  'companyOfficers': [],
#  'regularMarketPrice': 46.22,
#  'logo_url': ''}

# %%
VIX = yf.Ticker('VIX')

# %%
VIX
# Out:
# yfinance.Ticker object <VIX>

# %%
yinn.info
# Out:
# {'previousClose': 11.24,
#  'regularMarketOpen': 13.79,
#  'twoHundredDayAverage': 18.707884,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': None,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 13.82,
#  'navPrice': 13.14,
#  'averageDailyVolume10Day': 3852557,
#  'totalAssets': 342581760,
#  'regularMarketPreviousClose': 11.24,
#  'fiftyDayAverage': 17.460588,
#  'trailingAnnualDividendRate': None,
#  'open': 13.79,
#  'averageVolume10days': 3852557,
#  'expireDate': None,
#  'yield': 0.0177,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'beta': None,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 11.71,
#  'priceHint': 2,
#  'currency': 'USD',
#  'regularMarketVolume': 4666262,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': None,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 3219137,
#  'priceToSalesTrailing12Months': None,
#  'dayLow': 11.71,
#  'ask': 13.1,
#  'ytdReturn': None,
#  'askSize': 1300,
#  'volume': 4666262,
#  'fiftyTwoWeekHigh': 26.93,
#  'forwardPE': None,
#  'maxAge': 1,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 10.75,
#  'bid': 13.32,
#  'tradeable': True,
#  'dividendYield': None,
#  'bidSize': 3100,
#  'dayHigh': 13.82,
#  'exchange': 'PCX',
#  'shortName': 'Direxion Daily FTSE China Bull ',
#  'longName': 'Direxion Daily FTSE China Bull 3X Shares',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'ETF',
#  'symbol': 'YINN',
#  'messageBoardId': 'finmb_82488383',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': None,
#  'beta3Year': 2.83,
#  'profitMargins': None,
#  'enterpriseToEbitda': None,
#  '52WeekChange': None,
#  'morningStarRiskRating': None,
#  'forwardEps': None,
#  'revenueQuarterlyGrowth': None,
#  'fundInceptionDate': 1259798400,
#  'annualReportExpenseRatio': None,
#  'bookValue': None,
#  'fundFamily': 'Direxion Funds',
#  'lastFiscalYearEnd': None,
#  'netIncomeToCommon': None,
#  'trailingEps': None,
#  'lastDividendValue': None,
#  'SandP52WeekChange': None,
#  'priceToBook': None,
#  'nextFiscalYearEnd': None,
#  'mostRecentQuarter': None,
#  'enterpriseValue': None,
#  'threeYearAverageReturn': -0.1171,
#  'lastSplitDate': None,
#  'lastSplitFactor': None,
#  'legalType': 'Exchange Traded Fund',
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': None,
#  'pegRatio': None,
#  'lastCapGain': None,
#  'category': 'Trading--Leveraged Equity',
#  'fiveYearAverageReturn': -0.1694,
#  'phone': '866-476-7523',
#  'longBusinessSummary': 'The investment seeks daily investment results, before fees and expenses, of 300% of the daily performance of the FTSE China 50 Index.\n The fund, under normal circumstances, invests at least 80% of its net assets (plus borrowing for investment purposes) in financial instruments, such as swap agreements, and securities of the index, exchange-traded funds ("ETFs") that track the index and other financial instruments that provide daily leveraged exposure to the index or ETFs that track the index. The index consists of the 50 largest and most liquid public Chinese companies currently trading on the Stock Exchange of Hong Kong. The fund is non-diversified.',
#  'companyOfficers': [],
#  'regularMarketPrice': 13.79,
#  'logo_url': ''}

# %%
msft.info
# Out:
# {'zip': '98052',
#  'sector': 'Technology',
#  'fullTimeEmployees': 144000,
#  'longBusinessSummary': "Microsoft Corporation develops, licenses, and supports software, services, devices, and solutions worldwide. The company's Productivity and Business Processes segment offers Office, Exchange, SharePoint, Microsoft Teams, Office 365 Security and Compliance, and Skype for Business, as well as related Client Access Licenses (CAL); and Skype, Outlook.com, and OneDrive. It also provides LinkedIn that includes Talent and marketing solutions, and subscriptions; and Dynamics 365, a set of cloud-based and on-premises business solutions for small and medium businesses, large organizations, and divisions of enterprises. The company's Intelligent Cloud segment licenses SQL and Windows Servers, Visual Studio, System Center, and related CALs; GitHub that provides a collaboration platform and code hosting service for developers; and Azure, a cloud platform. It also provides support services and Microsoft consulting services to assist customers in developing, deploying, and managing Microsoft server and desktop solutions; and training and certification to developers and IT professionals on various Microsoft products. The company's More Personal Computing segment offers Windows OEM licensing and other non-volume licensing of the Windows operating system; Windows Commercial comprising volume licensing of the Windows operating system, Windows cloud services, and other Windows commercial offerings; patent licensing; Windows Internet of Things; and MSN advertising. It also provides Microsoft Surface, PC accessories, and other intelligent devices; Gaming, including Xbox hardware, and Xbox software and services; video games and third-party video game royalties; and Search, including Bing and Microsoft advertising. The company sells its products through distributors and resellers; and directly through digital marketplaces, online stores, and retail stores. It has strategic partnerships with Humana Inc. and Nokia. The company was founded in 1975 and is headquartered in Redmond, Washington.",
#  'city': 'Redmond',
#  'phone': '425-882-8080',
#  'state': 'WA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'http://www.microsoft.com',
#  'maxAge': 1,
#  'address1': 'One Microsoft Way',
#  'fax': '425-706-7329',
#  'industry': 'Software—Infrastructure',
#  'previousClose': 139.06,
#  'regularMarketOpen': 147.5,
#  'twoHundredDayAverage': 153.38832,
#  'trailingAnnualDividendYield': 0.013950814,
#  'payoutRatio': 0.32930002,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 160,
#  'navPrice': None,
#  'averageDailyVolume10Day': 71220000,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 139.06,
#  'fiftyDayAverage': 171.565,
#  'trailingAnnualDividendRate': 1.94,
#  'open': 147.5,
#  'averageVolume10days': 71220000,
#  'expireDate': None,
#  'yield': None,
#  'algorithm': None,
#  'dividendRate': 2.04,
#  'exDividendDate': 1589932800,
#  'beta': 1.091844,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 140.73,
#  'priceHint': 2,
#  'currency': 'USD',
#  'trailingPE': 27.66591,
#  'regularMarketVolume': 92727446,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 1208068866048,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 39077237,
#  'priceToSalesTrailing12Months': 8.998718,
#  'dayLow': 140.73,
#  'ask': 153,
#  'ytdReturn': None,
#  'askSize': 900,
#  'volume': 92727446,
#  'fiftyTwoWeekHigh': 190.7,
#  'forwardPE': 25.211111,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 2,
#  'fiftyTwoWeekLow': 115.52,
#  'bid': 152.62,
#  'tradeable': True,
#  'dividendYield': 0.0147,
#  'bidSize': 1200,
#  'dayHigh': 160,
#  'exchange': 'NMS',
#  'shortName': 'Microsoft Corporation',
#  'longName': 'Microsoft Corporation',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'MSFT',
#  'messageBoardId': 'finmb_21835',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 8.648,
#  'beta3Year': None,
#  'profitMargins': 0.33016,
#  'enterpriseToEbitda': 18.95,
#  '52WeekChange': 0.18278468,
#  'morningStarRiskRating': None,
#  'forwardEps': 6.3,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 7606049792,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'bookValue': 14.467,
#  'sharesShort': 37031775,
#  'sharesPercentSharesOut': 0.0049,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1561852800,
#  'heldPercentInstitutions': 0.74410003,
#  'netIncomeToCommon': 44323000320,
#  'trailingEps': 5.741,
#  'lastDividendValue': None,
#  'SandP52WeekChange': -0.124358475,
#  'priceToBook': 10.97878,
#  'heldPercentInsiders': 0.01421,
#  'nextFiscalYearEnd': 1625011200,
#  'mostRecentQuarter': 1577750400,
#  'shortRatio': 0.82,
#  'sharesShortPreviousMonthDate': 1580428800,
#  'floatShares': 7495150845,
#  'enterpriseValue': 1160984395776,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1045526400,
#  'lastSplitFactor': '2:1',
#  'legalType': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.383,
#  'dateShortInterest': 1582848000,
#  'pegRatio': 1.65,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0049,
#  'sharesShortPriorMonth': 56674560,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'regularMarketPrice': 147.5,
#  'logo_url': 'https://logo.clearbit.com/microsoft.com'}

# %%
hist = msft.history(period='max')

# %%
hist.loc[hist.Dividends != 0]
# Out:
#               Open    High     Low   Close     Volume  Dividends  Stock Splits
# Date
# 2003-02-19   15.98   16.01   15.56   15.79   46902700       0.08           0.0
# 2003-10-15   18.90   18.94   18.58   18.82   57242100       0.16           0.0
# 2004-08-23   17.70   17.74   17.61   17.68   39572200       0.08           0.0
# 2004-11-15   19.78   19.90   19.68   19.82  104468000       3.08           0.0
# 2005-02-15   18.87   18.93   18.77   18.82   76551600       0.08           0.0
# ...            ...     ...     ...     ...        ...        ...           ...
# 2019-02-20  106.45  106.53  104.90  105.75   21607700       0.46           0.0
# 2019-05-15  123.09  125.52  122.54  124.83   24722700       0.46           0.0
# 2019-08-14  135.53  136.08  132.85  133.16   32527300       0.46           0.0
# 2019-11-20  149.90  150.43  148.06  149.21   25696800       0.51           0.0
# 2020-02-19  188.06  188.18  186.47  187.28   29997500       0.51           0.0
#
# [65 rows x 7 columns]

# %%
msft.
# Out:
# <bound method TickerBase.get_sustainability of yfinance.Ticker object <MSFT>>

# %%
msft.recommendations.last
# Out:
# <bound method NDFrame.last of                           Firm        To Grade From Grade Action
# Date
# 2012-07-20  Griffin Securities             Buy              init
# 2012-07-20       Goldman Sachs         Neutral              main
# 2012-08-20    Longbow Research             Buy              init
# 2012-09-12           Jefferies            Hold              init
# 2012-10-01         RBC Capital  Sector Perform              down
# ...                        ...             ...        ...    ...
# 2019-12-17       Deutsche Bank             Buy              main
# 2020-01-08      Morgan Stanley      Overweight              main
# 2020-01-09             Wedbush      Outperform              main
# 2020-01-09         Cowen & Co.      Outperform              main
# 2020-01-10           Jefferies             Buy              main
#
# [226 rows x 4 columns]>

# %%
aapl = yf.Ticker("AAPL")

# %%
aapl.earnings
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
aapl.financials
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
aapl.balance_sheet
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
import yfinance as yf

msft = yf.Ticker("MSFT")

#msft.history(..., proxy="PROXY_SERVER")
msft.get_actions(proxy="PROXY_SERVER")
# msft.get_dividends(proxy="PROXY_SERVER")
# msft.get_splits(proxy="PROXY_SERVER")
# msft.get_balance_sheet(proxy="PROXY_SERVER")
# msft.get_cashflow(proxy="PROXY_SERVER")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# ~/opt/anaconda3/lib/python3.7/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     593             if is_new_proxy_conn:
# --> 594                 self._prepare_proxy(conn)
#     595
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _prepare_proxy(self, conn)
#     804         conn.set_tunnel(self._proxy_host, self.port, self.proxy_headers)
# --> 805         conn.connect()
#     806
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x11e130e10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPSConnectionPool(host='query1.finance.yahoo.com', port=443): Max retries exceeded with url: /v8/finance/chart/MSFT?period1=-2208988800&period2=1584663043&interval=1d&includePrePost=False&events=div%2Csplits (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x11e130e10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')))
#
# During handling of the above exception, another exception occurred:
#
# ProxyError                                Traceback (most recent call last)
# <ipython-input-42-10fc5b9c4cbf> in <module>
#       4
#       5 #msft.history(..., proxy="PROXY_SERVER")
# ----> 6 msft.get_actions(proxy="PROXY_SERVER")
#       7 # msft.get_dividends(proxy="PROXY_SERVER")
#       8 # msft.get_splits(proxy="PROXY_SERVER")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/yfinance/base.py in get_actions(self, proxy)
#     471     def get_actions(self, proxy=None):
#     472         if self._history is None:
# --> 473             self.history(period="max", proxy=proxy)
#     474         actions = self._history[["Dividends", "Stock Splits"]]
#     475         return actions[actions != 0].dropna(how='all').fillna(0)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/yfinance/base.py in history(self, period, interval, start, end, prepost, actions, auto_adjust, back_adjust, proxy, rounding, tz, **kwargs)
#     148         # Getting data from json
#     149         url = "{}/v8/finance/chart/{}".format(self._base_url, self.ticker)
# --> 150         data = _requests.get(url=url, params=params, proxies=proxy)
#     151         if "Will be right back" in data.text:
#     152             raise RuntimeError("*** YAHOO! FINANCE IS CURRENTLY DOWN! ***\n"
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     508
#     509             if isinstance(e.reason, _ProxyError):
# --> 510                 raise ProxyError(e, request=request)
#     511
#     512             if isinstance(e.reason, _SSLError):
#
# ProxyError: HTTPSConnectionPool(host='query1.finance.yahoo.com', port=443): Max retries exceeded with url: /v8/finance/chart/MSFT?period1=-2208988800&period2=1584663043&interval=1d&includePrePost=False&events=div%2Csplits (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x11e130e10>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known')))
